# %% [markdown]
# # Predictions on Small Group Conversations

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# Enable inline plotting
# %matplotlib inline

# %%
# read in data
pd.read_csv('../../csv/gap_corpus.csv')
# Out:
#    median idt  avg ipp     ids  avg sol     cf-s     cf-w   psr-s   psr-w  \
# 0        16.0     82.8  0.0193     0.87   897.33  1527.33  0.2605  0.0931
# 1         3.5    100.0  0.0625     1.04    45.00    93.00  0.3117  0.1111
# 2         8.5    100.0  0.0000     1.47  2824.00  9019.50  0.4372  0.1708
# 3        10.0     71.4  0.1051     1.01   301.75   468.50  0.3750  0.1446
#
#     nsr-s   nsr-w  aoa  cnc  fam  img
# 0  0.0924  0.0270   79   49   10   70
# 1  0.0909  0.0303  474    9    4   13
# 2  0.1694  0.0409  122    0    9    0
# 3  0.1917  0.0489  367   17    7   57
